# %% [markdown]
# # Data Augmentation Demonstration

# %% [markdown]
# Automunge is available now for pip install:

# %%
# !pip install Automunge

# %% [markdown]
# Or to upgrade (we currently roll out upgrades pretty frequently):

# %%
# !pip install Automunge --upgrade

# %% [markdown]
# Once installed, run this in a local session to initialize:

# %%
from Automunge import Automunger
am = Automunger.AutoMunge()

# %% [markdown]
# We'll demonstrate data augmentation on the Titanic set, a common benchmark. Importantly, in order to perform feature importance we'll need to include and designate a target label column.

# %%
import pandas as pd

#titanic set
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

#titanic set
labels_column = 'Survived'
trainID_column = 'PassengerId'

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# We can then perform feature importance in automunge(.) by the featureselection parameter. The results will be included about midway through the printouts and also available for inspections in the returned featureimprotance dicitonary.
#
# Note that automunge(.) performs feature importance by way of shuffle permutation, and relies on the same ML architecture used for ML infill, which in default configuration is Random Forest.

# %%
train, trainID, labels, \
validation1, validationID1, validationlabels1, \
validation2, validationID2, validationlabels2, \
test, testID, testlabels, \
labelsencoding_dict, finalcolumns_train, finalcolumns_test, \
featureimportance, postprocess_dict \
= am.automunge(df_train,
               labels_column = labels_column,
               trainID_column = trainID_column,
               featureselection = True,
               printstatus = True)
# Out:
# _______________
# Begin Feature Importance evaluation
#
# _______________
# Begin Automunge processing
#
# evaluating column:  Pclass
# processing column:  Pclass
#     root category:  text
#  returned columns:
# ['Pclass_1.0', 'Pclass_2.0', 'Pclass_3.0']
#
# evaluating column:  Name
# processing column:  Name
#     root category:  hash
#  returned columns:
# ['Name_hash_0', 'Name_hash_1', 'Name_hash_2', 'Name_hash_3', 'Name_hash_4', 'Name_hash_5', 'Name_hash_6', 'Name_hash_7', 'Name_hash_8', 'Name_hash_9', 'Name_hash_10', 'Name_hash_11', 'Name_hash_12', 'Name_hash_13']
#
# evaluating column:  Sex
# processing column:  Sex
#     root category:  bnry
#  returned columns:
# ['Sex_bnry']
#
# evaluating column:  Age
# processing column:  Age
#     root category:  nmbr
#  returned columns:
# ['Age_nmbr']
#
# evaluating column:  SibSp
# processing column:  SibSp
#     root category:  nmbr
#  returned columns:
# ['SibSp_nmbr']
#
# evaluating column:  Parch
# processing column:  Parch
#     root category:  nmbr
#  returned columns:
# ['Parch_nmbr']
#
# evaluating column:  Ticket
# processing column:  Ticket
#     root category:  hash
#  returned columns:
# ['Ticket_hash_0', 'Ticket_hash_1', 'Ticket_hash_2']
#
# evaluating column:  Fare
# processing column:  Fare
#     root category:  nmbr
#  returned columns:
# ['Fare_nmbr']
#
# evaluating column:  Cabin
# processing column:  Cabin
#     root category:  1010
#  returned columns:
# ['Cabin_1010_0', 'Cabin_1010_1', 'Cabin_1010_2', 'Cabin_1010_3', 'Cabin_1010_4', 'Cabin_1010_5', 'Cabin_1010_6']
#
# evaluating column:  Embarked
# processing column:  Embarked
#     root category:  1010
#  returned columns:
# ['Embarked_1010_0', 'Embarked_1010_1']
#
# ______
#
# evaluating label column:  Survived
# processing label column:  Survived
#     root label category:  lbbn
#
#  returned columns:
# ['Survived_0.0', 'Survived_1.0']
#
# ______
#
# infill to column:  Sex_bnry
#      infill type: stdrdinfill
#
# infill to column:  Age_nmbr
#      infill type: stdrdinfill
#
# infill to column:  SibSp_nmbr
#      infill type: stdrdinfill
#
# infill to column:  Parch_nmbr
#      infill type: stdrdinfill
#
# infill to column:  Fare_nmbr
#      infill type: stdrdinfill
#
# infill to column:  Pclass_1.0
#      infill type: stdrdinfill
#
# infill to column:  Pclass_2.0
#      infill type: stdrdinfill
#
# infill to column:  Pclass_3.0
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_0
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_1
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_2
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_3
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_4
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_5
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_6
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_7
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_8
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_9
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_10
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_11
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_12
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_13
#      infill type: stdrdinfill
#
# infill to column:  Ticket_hash_0
#      infill type: stdrdinfill
#
# infill to column:  Ticket_hash_1
#      infill type: stdrdinfill
#
# infill to column:  Ticket_hash_2
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_0
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_1
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_2
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_3
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_4
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_5
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_6
#      infill type: stdrdinfill
#
# infill to column:  Embarked_1010_0
#      infill type: stdrdinfill
#
# infill to column:  Embarked_1010_1
#      infill type: stdrdinfill
#
# _______________
# Begin Validation set processing with Postmunge
#
# _______________
# Begin Postmunge processing
#
# ______
#
# processing column:  Pclass
#     root category:  text
#
#  returned columns:
# ['Pclass_1.0', 'Pclass_2.0', 'Pclass_3.0']
#
# ______
#
# processing column:  Name
#     root category:  hash
#
#  returned columns:
# ['Name_hash_0', 'Name_hash_1', 'Name_hash_2', 'Name_hash_3', 'Name_hash_4', 'Name_hash_5', 'Name_hash_6', 'Name_hash_7', 'Name_hash_8', 'Name_hash_9', 'Name_hash_10', 'Name_hash_11', 'Name_hash_12', 'Name_hash_13']
#
# ______
#
# processing column:  Sex
#     root category:  bnry
#
#  returned columns:
# ['Sex_bnry']
#
# ______
#
# processing column:  Age
#     root category:  nmbr
#
#  returned columns:
# ['Age_nmbr']
#
# ______
#
# processing column:  SibSp
#     root category:  nmbr
#
#  returned columns:
# ['SibSp_nmbr']
#
# ______
#
# processing column:  Parch
#     root category:  nmbr
#
#  returned columns:
# ['Parch_nmbr']
#
# ______
#
# processing column:  Ticket
#     root category:  hash
#
#  returned columns:
# ['Ticket_hash_0', 'Ticket_hash_1', 'Ticket_hash_2']
#
# ______
#
# processing column:  Fare
#     root category:  nmbr
#
#  returned columns:
# ['Fare_nmbr']
#
# ______
#
# processing column:  Cabin
#     root category:  1010
#
#  returned columns:
# ['Cabin_1010_0', 'Cabin_1010_1', 'Cabin_1010_2', 'Cabin_1010_3', 'Cabin_1010_4', 'Cabin_1010_5', 'Cabin_1010_6']
#
# ______
#
# processing column:  Embarked
#     root category:  1010
#
#  returned columns:
# ['Embarked_1010_0', 'Embarked_1010_1']
#
# ______
#
# processing label column:  Survived
#     root label category:  lbbn
#
#  returned columns:
# ['Survived_0.0', 'Survived_1.0']
#
# ______
#
# infill to column:  Sex_bnry
#      infill type: stdrdinfill
#
# infill to column:  Age_nmbr
#      infill type: stdrdinfill
#
# infill to column:  SibSp_nmbr
#      infill type: stdrdinfill
#
# infill to column:  Parch_nmbr
#      infill type: stdrdinfill
#
# infill to column:  Fare_nmbr
#      infill type: stdrdinfill
#
# infill to column:  Pclass_1.0
#      infill type: stdrdinfill
#
# infill to column:  Pclass_2.0
#      infill type: stdrdinfill
#
# infill to column:  Pclass_3.0
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_0
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_1
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_2
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_3
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_4
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_5
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_6
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_7
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_8
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_9
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_10
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_11
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_12
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_13
#      infill type: stdrdinfill
#
# infill to column:  Ticket_hash_0
#      infill type: stdrdinfill
#
# infill to column:  Ticket_hash_1
#      infill type: stdrdinfill
#
# infill to column:  Ticket_hash_2
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_0
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_1
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_2
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_3
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_4
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_5
#      infill type: stdrdinfill
#
# infill to column:  Cabin_1010_6
#      infill type: stdrdinfill
#
# infill to column:  Embarked_1010_0
#      infill type: stdrdinfill
#
# infill to column:  Embarked_1010_1
#      infill type: stdrdinfill
#
# _______________
# Postmunge returned ID column set:
# ['Automunge_index_246027927999']
#
# Postmunge returned test column set:
# ['Sex_bnry', 'Age_nmbr', 'SibSp_nmbr', 'Parch_nmbr', 'Fare_nmbr', 'Pclass_1.0', 'Pclass_2.0', 'Pclass_3.0', 'Name_hash_0', 'Name_hash_1', 'Name_hash_2', 'Name_hash_3', 'Name_hash_4', 'Name_hash_5', 'Name_hash_6', 'Name_hash_7', 'Name_hash_8', 'Name_hash_9', 'Name_hash_10', 'Name_hash_11', 'Name_hash_12', 'Name_hash_13', 'Ticket_hash_0', 'Ticket_hash_1', 'Ticket_hash_2', 'Cabin_1010_0', 'Cabin_1010_1', 'Cabin_1010_2', 'Cabin_1010_3', 'Cabin_1010_4', 'Cabin_1010_5', 'Cabin_1010_6', 'Embarked_1010_0', 'Embarked_1010_1']
#
# Postmunge returned label column set:
# ['Survived_0.0', 'Survived_1.0']
#
# _______________
# Postmunge Complete
#
# ______
#
# versioning serial stamp:
# _5.55_246027927999_2021-01-31T20:35:57.681249
#
# Automunge returned ID column set:
# ['PassengerId', 'Automunge_index_246027927999']
#
# Automunge returned train column set:
# ['Sex_bnry', 'Age_nmbr', 'SibSp_nmbr', 'Parch_nmbr', 'Fare_nmbr', 'Pclass_1.0', 'Pclass_2.0', 'Pclass_3.0', 'Name_hash_0', 'Name_hash_1', 'Name_hash_2', 'Name_hash_3', 'Name_hash_4', 'Name_hash_5', 'Name_hash_6', 'Name_hash_7', 'Name_hash_8', 'Name_hash_9', 'Name_hash_10', 'Name_hash_11', 'Name_hash_12', 'Name_hash_13', 'Ticket_hash_0', 'Ticket_hash_1', 'Ticket_hash_2', 'Cabin_1010_0', 'Cabin_1010_1', 'Cabin_1010_2', 'Cabin_1010_3', 'Cabin_1010_4', 'Cabin_1010_5', 'Cabin_1010_6', 'Embarked_1010_0', 'Embarked_1010_1']
#
# Automunge returned label column set:
# ['Survived_0.0', 'Survived_1.0']
#
# _______________
# Automunge Complete
#
# _______________
# Training feature importance evaluation model
# Base Accuracy of feature importance model:
# 0.8491620111731844
#
# _______________
# Evaluating feature importances
#
# _______________
# Feature Importance results:
#
# Sex_bnry
# metric =  0.08938547486033521
# metric2 =  0.0
#
# Age_nmbr
# metric =  0.04469273743016755
# metric2 =  0.0
#
# SibSp_nmbr
# metric =  0.011173184357541888
# metric2 =  0.0
#
# Parch_nmbr
# metric =  0.0
# metric2 =  0.0
#
# Fare_nmbr
# metric =  0.03910614525139666
# metric2 =  0.0
#
# Pclass_1.0
# metric =  0.016759776536312887
# metric2 =  0.011173184357541888
#
# Pclass_2.0
# metric =  0.016759776536312887
# metric2 =  0.005586592178770888
#
# Pclass_3.0
# metric =  0.016759776536312887
# metric2 =  -0.005586592178770999
#
# Name_hash_0
# metric =  0.08379888268156421
# metric2 =  0.08379888268156421
#
# Name_hash_1
# metric =  0.08379888268156421
# metric2 =  0.0
#
# Name_hash_2
# metric =  0.08379888268156421
# metric2 =  0.07821229050279332
#
# Name_hash_3
# metric =  0.08379888268156421
# metric2 =  0.07821229050279332
#
# Name_hash_4
# metric =  0.08379888268156421
# metric2 =  0.07262569832402233
#
# Name_hash_5
# metric =  0.08379888268156421
# metric2 =  0.06703910614525144
#
# Name_hash_6
# metric =  0.08379888268156421
# metric2 =  0.08379888268156421
#
# Name_hash_7
# metric =  0.08379888268156421
# metric2 =  0.08379888268156421
#
# Name_hash_8
# metric =  0.08379888268156421
# metric2 =  0.08379888268156421
#
# Name_hash_9
# metric =  0.08379888268156421
# metric2 =  0.08379888268156421
#
# Name_hash_10
# metric =  0.08379888268156421
# metric2 =  0.08379888268156421
#
# Name_hash_11
# metric =  0.08379888268156421
# metric2 =  0.08379888268156421
#
# Name_hash_12
# metric =  0.08379888268156421
# metric2 =  0.08379888268156421
#
# Name_hash_13
# metric =  0.08379888268156421
# metric2 =  0.08379888268156421
#
# Ticket_hash_0
# metric =  0.016759776536312887
# metric2 =  0.005586592178770888
#
# Ticket_hash_1
# metric =  0.016759776536312887
# metric2 =  0.011173184357541888
#
# Ticket_hash_2
# metric =  0.016759776536312887
# metric2 =  0.016759776536312887
#
# Cabin_1010_0
# metric =  0.011173184357541888
# metric2 =  0.011173184357541888
#
# Cabin_1010_1
# metric =  0.011173184357541888
# metric2 =  0.005586592178770888
#
# Cabin_1010_2
# metric =  0.011173184357541888
# metric2 =  0.011173184357541888
#
# Cabin_1010_3
# metric =  0.011173184357541888
# metric2 =  0.011173184357541888
#
# Cabin_1010_4
# metric =  0.011173184357541888
# metric2 =  0.016759776536312887
#
# Cabin_1010_5
# metric =  0.011173184357541888
# metric2 =  0.011173184357541888
#
# Cabin_1010_6
# metric =  0.011173184357541888
# metric2 =  0.011173184357541888
#
# Embarked_1010_0
# metric =  0.05027932960893855
# metric2 =  0.005586592178770888
#
# Embarked_1010_1
# metric =  0.05027932960893855
# metric2 =  0.027932960893854775
#
#
# ______________________
# sorted metric results:
#
# Sex
# 0.08938547486033521
#
# Name
# 0.08379888268156421
#
# Embarked
# 0.05027932960893855
#
# Age
# 0.04469273743016755
#
# Fare
# 0.03910614525139666
#
# Pclass
# 0.016759776536312887
#
# Ticket
# 0.016759776536312887
#
# SibSp
# 0.011173184357541888
#
# Cabin
# 0.011173184357541888
#
# Parch
# 0.0
#
# ______________________
# sorted metric2 results:
#
# for source column:  Pclass
# Pclass_3.0
# -0.005586592178770999
#
# Pclass_2.0
# 0.005586592178770888
#
# Pclass_1.0
# 0.011173184357541888
#
#
# for source column:  Name
# Name_hash_1
# 0.0
#
# Name_hash_5
# 0.06703910614525144
#
# Name_hash_4
# 0.07262569832402233
#
# Name_hash_2
# 0.07821229050279332
#
# Name_hash_3
# 0.07821229050279332
#
# Name_hash_0
# 0.08379888268156421
#
# Name_hash_6
# 0.08379888268156421
#
# Name_hash_7
# 0.08379888268156421
#
# Name_hash_8
# 0.08379888268156421
#
# Name_hash_9
# 0.08379888268156421
#
# Name_hash_10
# 0.08379888268156421
#
# Name_hash_11
# 0.08379888268156421
#
# Name_hash_12
# 0.08379888268156421
#
# Name_hash_13
# 0.08379888268156421
#
#
# for source column:  Sex
# Sex_bnry
# 0.0
#
#
# for source column:  Age
# Age_nmbr
# 0.0
#
#
# for source column:  SibSp
# SibSp_nmbr
# 0.0
#
#
# for source column:  Parch
# Parch_nmbr
# 0.0
#
#
# for source column:  Ticket
# Ticket_hash_0
# 0.005586592178770888
#
# Ticket_hash_1
# 0.011173184357541888
#
# Ticket_hash_2
# 0.016759776536312887
#
#
# for source column:  Fare
# Fare_nmbr
# 0.0
#
#
# for source column:  Cabin
# Cabin_1010_1
# 0.005586592178770888
#
# Cabin_1010_0
# 0.011173184357541888
#
# Cabin_1010_2
# 0.011173184357541888
#
# Cabin_1010_3
# 0.011173184357541888
#
# Cabin_1010_5
# 0.011173184357541888
#
# Cabin_1010_6
# 0.011173184357541888
#
# Cabin_1010_4
# 0.016759776536312887
#
#
# for source column:  Embarked
# Embarked_1010_0
# 0.005586592178770888
#
# Embarked_1010_1
# 0.027932960893854775
#
#
# for source column:  Survived
#
# _______________
# Feature Importance evaluation complete
#
# _______________
# Begin Automunge processing
#
# evaluating column:  Pclass
# processing column:  Pclass
#     root category:  text
#  returned columns:
# ['Pclass_1.0', 'Pclass_2.0', 'Pclass_3.0']
#
# evaluating column:  Name
# processing column:  Name
#     root category:  hash
#  returned columns:
# ['Name_hash_0', 'Name_hash_1', 'Name_hash_2', 'Name_hash_3', 'Name_hash_4', 'Name_hash_5', 'Name_hash_6', 'Name_hash_7', 'Name_hash_8', 'Name_hash_9', 'Name_hash_10', 'Name_hash_11', 'Name_hash_12', 'Name_hash_13']
#
# evaluating column:  Sex
# processing column:  Sex
#     root category:  bnry
#  returned columns:
# ['Sex_bnry']
#
# evaluating column:  Age
# processing column:  Age
#     root category:  nmbr
#  returned columns:
# ['Age_nmbr']
#
# evaluating column:  SibSp
# processing column:  SibSp
#     root category:  nmbr
#  returned columns:
# ['SibSp_nmbr']
#
# evaluating column:  Parch
# processing column:  Parch
#     root category:  nmbr
#  returned columns:
# ['Parch_nmbr']
#
# evaluating column:  Ticket
# processing column:  Ticket
#     root category:  hash
#  returned columns:
# ['Ticket_hash_0', 'Ticket_hash_1', 'Ticket_hash_2']
#
# evaluating column:  Fare
# processing column:  Fare
#     root category:  nmbr
#  returned columns:
# ['Fare_nmbr']
#
# evaluating column:  Cabin
# processing column:  Cabin
#     root category:  hsh2
#  returned columns:
# ['Cabin_hash']
#
# evaluating column:  Embarked
# processing column:  Embarked
#     root category:  1010
#  returned columns:
# ['Embarked_1010_0', 'Embarked_1010_1']
#
# ______
#
# evaluating label column:  Survived
# processing label column:  Survived
#     root label category:  lbbn
#
#  returned columns:
# ['Survived_0.0', 'Survived_1.0']
#
# ______
#
# infill to column:  Sex_bnry
#      infill type: stdrdinfill
#
# infill to column:  Age_nmbr
#      infill type: stdrdinfill
#
# infill to column:  SibSp_nmbr
#      infill type: stdrdinfill
#
# infill to column:  Parch_nmbr
#      infill type: stdrdinfill
#
# infill to column:  Fare_nmbr
#      infill type: stdrdinfill
#
# infill to column:  Cabin_hash
#      infill type: stdrdinfill
#
# infill to column:  Pclass_1.0
#      infill type: stdrdinfill
#
# infill to column:  Pclass_2.0
#      infill type: stdrdinfill
#
# infill to column:  Pclass_3.0
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_0
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_1
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_2
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_3
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_4
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_5
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_6
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_7
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_8
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_9
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_10
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_11
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_12
#      infill type: stdrdinfill
#
# infill to column:  Name_hash_13
#      infill type: stdrdinfill
#
# infill to column:  Ticket_hash_0
#      infill type: stdrdinfill
#
# infill to column:  Ticket_hash_1
#      infill type: stdrdinfill
#
# infill to column:  Ticket_hash_2
#      infill type: stdrdinfill
#
# infill to column:  Embarked_1010_0
#      infill type: stdrdinfill
#
# infill to column:  Embarked_1010_1
#      infill type: stdrdinfill
#
# ______
#
# versioning serial stamp:
# _5.55_655145289108_2021-01-31T20:35:57.668874
#
# Automunge returned ID column set:
# ['PassengerId', 'Automunge_index_655145289108']
#
# Automunge returned train column set:
# ['Sex_bnry', 'Age_nmbr', 'SibSp_nmbr', 'Parch_nmbr', 'Fare_nmbr', 'Cabin_hash', 'Pclass_1.0', 'Pclass_2.0', 'Pclass_3.0', 'Name_hash_0', 'Name_hash_1', 'Name_hash_2', 'Name_hash_3', 'Name_hash_4', 'Name_hash_5', 'Name_hash_6', 'Name_hash_7', 'Name_hash_8', 'Name_hash_9', 'Name_hash_10', 'Name_hash_11', 'Name_hash_12', 'Name_hash_13', 'Ticket_hash_0', 'Ticket_hash_1', 'Ticket_hash_2', 'Embarked_1010_0', 'Embarked_1010_1']
#
# Automunge returned label column set:
# ['Survived_0.0', 'Survived_1.0']
#
# _______________
# Automunge Complete

# %% [markdown]
# The results included in prinouts are first presented in order of features and then again sorted by the metric from most important to least.
#
# Here "metric" measures the importance of the source column and a higher value implies higher importance.
#
# And "metric2" measures the relative importance of features derived from the same source column and a lower value implies higher relative importance.
#
# Important to keep in mind that feature importance is as much a measure of the model as it is of the feature.

# %% [markdown]
# We can also inspect results in the returned featureimportance dictionary.
#
# Here featureimportance['FS_sorted'] are the results sorted by the metric, and featureimportance['FScolumn_dict'] are the raw unsorted data. Each aggragation includes the data in a few different formats.

# %%
#Here are the sorted metric results 

featureimportance['FS_sorted']['metric_key']
# Out:
# {0.08938547486033521: ['Sex'],
#  0.08379888268156421: ['Name'],
#  0.05027932960893855: ['Embarked'],
#  0.04469273743016755: ['Age'],
#  0.03910614525139666: ['Fare'],
#  0.016759776536312887: ['Pclass', 'Ticket'],
#  0.011173184357541888: ['SibSp', 'Cabin'],
#  0.0: ['Parch']}

# %%
#or as an inversion of that presentation

featureimportance['FS_sorted']['column_key']
# Out:
# {'Sex': 0.08938547486033521,
#  'Name': 0.08379888268156421,
#  'Embarked': 0.05027932960893855,
#  'Age': 0.04469273743016755,
#  'Fare': 0.03910614525139666,
#  'Pclass': 0.016759776536312887,
#  'Ticket': 0.016759776536312887,
#  'SibSp': 0.011173184357541888,
#  'Cabin': 0.011173184357541888,
#  'Parch': 0.0}
